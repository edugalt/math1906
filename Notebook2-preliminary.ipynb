# %% [markdown]
# # MATH 1906, Chaos in Dynamical Systems
#
# ## 2- Logistic Equation
#
# ## Lecturer: Eduardo G. Altmann
#
# Key concepts are marked in <font color="red"> red </font>.
# <br> More on Jupyter notebooks: <a href="www.jupyter.org"> www.jupyter.org </a>

# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 2- A simple model
#
# ## 2.1 Motivation for the Logistic Equation
#
# $$ x_{t+1} = F(x_t)$$
# $$ x_{t+1} = a x_t (1-x_t)$$

# %% [markdown]
# ## 2.2 Numerical Explorations

# %%
def f(x,a):
    return a*x*(1-x)

# %%
x=np.array([0.81131431,0.13443,0.26575])

# %%
listx=[]
listt=[]
for t in range(30):
    listx.append(x)
    listt.append(t)
    x=f(x,10.0/3)

# %%
plot(listt,listx,'-o')
# Out:
# <img src="data:image/png;base64,...">
# ...

# %% [markdown]
# #### <font color=red> Fixed points </red>
#
# $$ x^{(1)}= 1-1/a$$

# %% [markdown]
# Homework: Periodic orbit of period 2?
